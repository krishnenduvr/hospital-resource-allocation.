# %%
import pandas as pd

# %%
a=pd.read_csv("host_train.csv")
a
# Out:
#         case_id  Hospital  Hospital_type  Hospital_city  Hospital_region  \
# 0             1         8              2              3                2
# 1             2         2              2              5                2
# 2             3        10              4              1                0
# 3             4        26              1              2                1
# 4             5        26              1              2                1
# ...         ...       ...            ...            ...              ...
# 318433   318434         6              0              6                0
# 318434   318435        24              0              1                0
# 318435   318436         7              0              4                0
# 318436   318437        11              1              2                1
# 318437   318438        19              0              7                1
#
#         Available_Extra_Rooms_in_Hospital    Department Ward_Type  \
# ...

# %%
a.head()
# Out:
#    case_id  Hospital  Hospital_type  Hospital_city  Hospital_region  \
# 0        1         8              2              3                2
# 1        2         2              2              5                2
# 2        3        10              4              1                0
# 3        4        26              1              2                1
# 4        5        26              1              2                1
#
#    Available_Extra_Rooms_in_Hospital    Department Ward_Type Ward_Facility  \
# 0                                  3  radiotherapy         R             F
# 1                                  2  radiotherapy         S             F
# 2                                  2    anesthesia         S             E
# 3                                  2  radiotherapy         R             D
# 4                                  2  radiotherapy         S             D
#
#    Bed_Grade  patientid  City_Code_Patient Type of Admission Illness_Severity  \
# ...

# %%
a.tail()
# Out:
#         case_id  Hospital  Hospital_type  Hospital_city  Hospital_region  \
# 318433   318434         6              0              6                0
# 318434   318435        24              0              1                0
# 318435   318436         7              0              4                0
# 318436   318437        11              1              2                1
# 318437   318438        19              0              7                1
#
#         Available_Extra_Rooms_in_Hospital    Department Ward_Type  \
# 318433                                  3  radiotherapy         Q
# 318434                                  2    anesthesia         Q
# 318435                                  3    gynecology         R
# 318436                                  3    anesthesia         Q
# 318437                                  5    gynecology         Q
#
#        Ward_Facility  Bed_Grade  patientid  City_Code_Patient  \
# 318433             F        4.0      86499               23.0
# ...

# %%
a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 318438 entries, 0 to 318437
# Data columns (total 18 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   case_id                            318438 non-null  int64
#  1   Hospital                           318438 non-null  int64
#  2   Hospital_type                      318438 non-null  int64
#  3   Hospital_city                      318438 non-null  int64
#  4   Hospital_region                    318438 non-null  int64
#  5   Available_Extra_Rooms_in_Hospital  318438 non-null  int64
#  6   Department                         318438 non-null  object
#  7   Ward_Type                          318438 non-null  object
#  8   Ward_Facility                      318438 non-null  object
#  9   Bed_Grade                          318325 non-null  float64
#  10  patientid                          318438 non-null  int64
# ...

# %%
a.describe()
# Out:
#              case_id       Hospital  Hospital_type  Hospital_city  \
# count  318438.000000  318438.000000  318438.000000  318438.000000
# mean   159219.500000      18.318841       1.256841       4.771717
# std     91925.276847       8.633755       1.535712       3.102535
# min         1.000000       1.000000       0.000000       1.000000
# 25%     79610.250000      11.000000       0.000000       2.000000
# 50%    159219.500000      19.000000       1.000000       5.000000
# 75%    238828.750000      26.000000       2.000000       7.000000
# max    318438.000000      32.000000       6.000000      13.000000
#
#        Hospital_region  Available_Extra_Rooms_in_Hospital      Bed_Grade  \
# count    318438.000000                      318438.000000  318325.000000
# mean          0.778098                           3.197627       2.625807
# std           0.752527                           1.168171       0.873146
# min           0.000000                           0.000000       1.000000
# ...

# %%
a.isnull().sum()
# Out:
# case_id                                 0
# Hospital                                0
# Hospital_type                           0
# Hospital_city                           0
# Hospital_region                         0
# Available_Extra_Rooms_in_Hospital       0
# Department                              0
# Ward_Type                               0
# Ward_Facility                           0
# Bed_Grade                             113
# patientid                               0
# City_Code_Patient                    4532
# Type of Admission                       0
# Illness_Severity                        0
# Patient_Visitors                        0
# Age                                     0
# Admission_Deposit                       0
# Stay_Days                               0
# dtype: int64

# %%
a.shape
# Out:
# (318438, 18)

# %%
b=a.fillna(method="ffill")
b
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_5012\3453344981.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   b=a.fillna(method="ffill")
#         case_id  Hospital  Hospital_type  Hospital_city  Hospital_region  \
# 0             1         8              2              3                2
# 1             2         2              2              5                2
# 2             3        10              4              1                0
# 3             4        26              1              2                1
# 4             5        26              1              2                1
# ...         ...       ...            ...            ...              ...
# 318433   318434         6              0              6                0
# 318434   318435        24              0              1                0
# 318435   318436         7              0              4                0
# ...

# %%
c=b.fillna(method="bfill")
c
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_5012\572931550.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   c=b.fillna(method="bfill")
#         case_id  Hospital  Hospital_type  Hospital_city  Hospital_region  \
# 0             1         8              2              3                2
# 1             2         2              2              5                2
# 2             3        10              4              1                0
# 3             4        26              1              2                1
# 4             5        26              1              2                1
# ...         ...       ...            ...            ...              ...
# 318433   318434         6              0              6                0
# 318434   318435        24              0              1                0
# 318435   318436         7              0              4                0
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
for column in c.select_dtypes(include=['object']).columns:
    c[column]=le.fit_transform(c[column])
c
# Out:
#         case_id  Hospital  Hospital_type  Hospital_city  Hospital_region  \
# 0             1         8              2              3                2
# 1             2         2              2              5                2
# 2             3        10              4              1                0
# 3             4        26              1              2                1
# 4             5        26              1              2                1
# ...         ...       ...            ...            ...              ...
# 318433   318434         6              0              6                0
# 318434   318435        24              0              1                0
# 318435   318436         7              0              4                0
# 318436   318437        11              1              2                1
# 318437   318438        19              0              7                1
#
#         Available_Extra_Rooms_in_Hospital  Department  Ward_Type  \
# ...

# %%
c.corr()
# Out:
#                                     case_id  Hospital  Hospital_type  \
# case_id                            1.000000 -0.043023       0.001877
# Hospital                          -0.043023  1.000000       0.039449
# Hospital_type                      0.001877  0.039449       1.000000
# Hospital_city                     -0.011352  0.128294      -0.000839
# Hospital_region                    0.006262 -0.135920       0.268962
# Available_Extra_Rooms_in_Hospital  0.042580 -0.059638      -0.103044
# Department                        -0.002175  0.000777       0.001768
# Ward_Type                         -0.029183  0.161108       0.246347
# Ward_Facility                     -0.011546 -0.132347      -0.265768
# Bed_Grade                          0.013757 -0.013541       0.018871
# patientid                         -0.004150  0.002291      -0.003010
# City_Code_Patient                  0.064564 -0.015362       0.054877
# Type of Admission                  0.076789 -0.014268       0.080073
# ...

# %%
d=c.drop(["case_id","Hospital_city","patientid","City_Code_Patient"],axis="columns")
d
# Out:
#         Hospital  Hospital_type  Hospital_region  \
# 0              8              2                2
# 1              2              2                2
# 2             10              4                0
# 3             26              1                1
# 4             26              1                1
# ...          ...            ...              ...
# 318433         6              0                0
# 318434        24              0                0
# 318435         7              0                0
# 318436        11              1                1
# 318437        19              0                1
#
#         Available_Extra_Rooms_in_Hospital  Department  Ward_Type  \
# 0                                       3           3          2
# 1                                       2           3          3
# 2                                       2           1          3
# 3                                       2           3          2
# ...

# %% [markdown]
# # Train Test Split

# %%
from sklearn.model_selection import train_test_split

# %%
e=d.drop(["Stay_Days"],axis="columns")
e
# Out:
#         Hospital  Hospital_type  Hospital_region  \
# 0              8              2                2
# 1              2              2                2
# 2             10              4                0
# 3             26              1                1
# 4             26              1                1
# ...          ...            ...              ...
# 318433         6              0                0
# 318434        24              0                0
# 318435         7              0                0
# 318436        11              1                1
# 318437        19              0                1
#
#         Available_Extra_Rooms_in_Hospital  Department  Ward_Type  \
# 0                                       3           3          2
# 1                                       2           3          3
# 2                                       2           1          3
# 3                                       2           3          2
# ...

# %%
f=d.Stay_Days
f
# Out:
# 0         0
# 1         4
# 2         3
# 3         4
# 4         4
#          ..
# 318433    1
# 318434    3
# 318435    1
# 318436    1
# 318437    0
# Name: Stay_Days, Length: 318438, dtype: int32

# %%
xtrain,xtest,ytrain,ytest=train_test_split(e,f,test_size=0.9)

# %% [markdown]
# # Logistic Regression

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
from sklearn.linear_model import LogisticRegression
model=LogisticRegression()

# %%
model.fit(xtrain,ytrain)
# Out:
# LogisticRegression()

# %%
model.predict(xtest)
# Out:
# array([2, 5, 2, ..., 2, 2, 5])

# %%
model.score(xtest,ytest)
# Out:
# 0.3279959524764912

# %% [markdown]
# # SVM(SUPPORT VECTOR MACHINE)

# %%
from sklearn.svm import SVC

# %%
model1=SVC()

# %%
model1.fit(xtrain,ytrain)
# Out:
# SVC()

# %%
model1.predict(xtest)
# Out:
# array([2, 1, 2, ..., 2, 2, 1])

# %%
model1.score(xtest,ytest)
# Out:
# 0.2746907657146845

# %% [markdown]
# # KERNELS-LINEAR,POLY,RBF

# %% [markdown]
# # LINEAR

# %%
model2=SVC(kernel="linear")
model2.fit(xtrain,ytrain)
# Out:
# SVC(kernel='linear')

# %%
model2.predict(xtest)
# Out:
# array([3, 5, 2, ..., 2, 1, 5])

# %%
model2.score(xtest,ytest)
# Out:
# 0.3740958495437813

# %% [markdown]
# # POLY

# %%
model3=SVC(kernel="poly")
model3.fit(xtrain,ytrain)
# Out:
# SVC(kernel='poly')

# %%
model3.predict(xtest)
# Out:
# array([2, 2, 2, ..., 2, 2, 2])

# %%
model3.score(xtest,ytest)
# Out:
# 0.27445349709520406

# %% [markdown]
# # RBF

# %%
model4=SVC(kernel="rbf")
model4.fit(xtrain,ytrain)
# Out:
# SVC()

# %%
model4.predict(xtest)
# Out:
# array([2, 1, 2, ..., 2, 2, 1])

# %%
model4.score(xtest,ytest)
# Out:
# 0.2746907657146845

# %% [markdown]
# # DECISION TREE CLASSIFIER

# %%
from sklearn import tree 
from sklearn.preprocessing import LabelEncoder

# %%
model5=tree.DecisionTreeClassifier()

# %%
model5.fit(xtrain,ytrain)
# Out:
# DecisionTreeClassifier()

# %%
model5.predict(xtest)
# Out:
# array([3, 9, 1, ..., 2, 3, 5])

# %%
model5.score(xtest,ytest)
# Out:
# 0.27925120815087495

# %% [markdown]
# # RANDOM FOREST CLASSIFIER

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
model6=RandomForestClassifier()

# %%
model6.fit(xtrain,ytrain)
# Out:
# RandomForestClassifier()

# %%
model6.predict(xtest)
# Out:
# array([5, 5, 1, ..., 1, 3, 5])

# %%
model6.score(xtest,ytest)
# Out:
# 0.36211029501561437

# %% [markdown]
# # KNEIGHBORS CLASSIFIER

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn=KNeighborsClassifier(n_neighbors=4)
knn.fit(xtrain,ytrain)
# Out:
# KNeighborsClassifier(n_neighbors=4)

# %%
knn.predict(xtest)
# Out:
# array([1, 3, 0, ..., 1, 1, 1])

# %%
knn.score(xtest,ytest)
# Out:
# 0.24186744360508733

# %% [markdown]
# # NAIVE_BAYES

# %%
from sklearn.naive_bayes import GaussianNB
classifier=GaussianNB()
classifier.fit(xtrain,ytrain)
# Out:
# GaussianNB()

# %%
classifier.predict(xtest)
# Out:
# array([3, 5, 2, ..., 2, 1, 5])

# %%
classifier.score(xtest,ytest)
# Out:
# 0.35827561541548175

# %% [markdown]
# # XGBOOST

# %%
from xgboost import XGBClassifier
model7 = XGBClassifier()

# %%
model7.fit(xtrain,ytrain)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, objective='multi:softprob', ...)

# %%
model7.predict(xtest)
# Out:
# array([3, 1, 1, ..., 2, 1, 3], dtype=int64)

# %%
model7.score(xtest,ytest)
# Out:
# 0.3956070412952075

# %% [markdown]
# # VISUALIZATION

# %%
import seaborn as sns
import matplotlib.pyplot as plt
readmission_counts = a["Stay_Days"].value_counts()
labels = readmission_counts.index
plt.figure(figsize=(6, 6))
plt.pie(readmission_counts.values, labels=labels, autopct="%.2f%%", colors=["skyblue", "salmon"])
plt.title("Stay_Days Distribution")
plt.show()

# %%
plt.figure(figsize=(12, 8))
sns.heatmap(c.corr(), annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Feature Correlation Heatmap")
plt.show()
